# %% [markdown]
# ## Sampling
# #### Read employees.csv file.
# #### Display column counts.
# #### Remove any row contains null and display column counts

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df_emp=pd.read_csv('/kaggle/input/employees/employees - employees.csv')

# %%
df_emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df_emp.count()
# Out:
# First Name            933
# Gender                855
# Start Date           1000
# Last Login Time      1000
# Salary               1000
# Bonus %              1000
# Senior Management     933
# Team                  957
# dtype: int64

# %%
df_emp.dropna(inplace=True)
df_emp.count()
# Out:
# First Name           764
# Gender               764
# Start Date           764
# Last Login Time      764
# Salary               764
# Bonus %              764
# Senior Management    764
# Team                 764
# dtype: int64

# %% [markdown]
# ## Simple Random Sample (SRS)
# #### Select simple random sample of size=50.
# #### Select 50% SRS.
# #### Display column counts in both cases.

# %%
df_50=df_emp.sample(n=50,random_state=42)
df_50.count()
# Out:
# First Name           50
# Gender               50
# Start Date           50
# Last Login Time      50
# Salary               50
# Bonus %              50
# Senior Management    50
# Team                 50
# dtype: int64

# %%
df_5=df_emp.sample(frac=.5,random_state=42)
df_5.count()
# Out:
# First Name           382
# Gender               382
# Start Date           382
# Last Login Time      382
# Salary               382
# Bonus %              382
# Senior Management    382
# Team                 382
# dtype: int64

# %% [markdown]
# ## Systematic Sampling
# #### Select a systematic sample with 25, 50, and 100 intervals.

# %%
np.random.seed(42)
intervals=[25,50,100]
for interval in intervals:
    sys_sample=df_emp.iloc[::interval]

# %%
np.random.seed(42)
sys_sample25=df_emp.iloc[::25]
sys_sample25
# Out:
#       First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0        Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 35       Theresa  Female  10/10/2006         1:12 AM   85182   16.675
# 68          Jose    Male  10/30/2004         1:39 PM   84834   14.330
# 101        Aaron    Male   2/17/2012        10:20 AM   61602   11.849
# 130      Shirley  Female    5/1/1984         1:15 PM   41334    6.219
# 167  Christopher    Male  12/24/2011        12:22 PM  142178   17.984
# 197      Carolyn  Female   11/6/2012         3:51 AM   69268    3.031
# 225        Harry    Male   10/1/2015         7:47 PM   64579   15.266
# 260       Gloria  Female   3/27/2007         1:44 AM   90730    2.491
# 294     Virginia  Female  10/20/1999         6:23 AM   46905   19.154
# 326      Jeffrey    Male   6/18/1997         8:01 PM   45150   12.075
# 355       Andrea  Female   9/14/2003        10:30 PM  115913   12.121
# ...

# %%
sys_sample50=df_emp.iloc[::50]
sys_sample50
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 68        Jose    Male  10/30/2004         1:39 PM   84834   14.330
# 130    Shirley  Female    5/1/1984         1:15 PM   41334    6.219
# 197    Carolyn  Female   11/6/2012         3:51 AM   69268    3.031
# 260     Gloria  Female   3/27/2007         1:44 AM   90730    2.491
# 326    Jeffrey    Male   6/18/1997         8:01 PM   45150   12.075
# 391    Marilyn  Female   8/15/1989         9:14 AM  140502    9.989
# 458     Albert    Male   9/30/2007         5:34 PM  102626   15.843
# 522  Catherine  Female   8/31/2013         7:24 PM   58047   14.858
# 584       Jack    Male   5/30/2012         3:17 AM   70367   18.266
# 653      Debra  Female   5/28/2006         6:51 AM   42296   16.922
# 725     Jeremy    Male   5/19/1991         1:40 PM  131513    1.876
# 796  Catherine  Female   8/31/1986         6:20 PM   59970   12.801
# ...

# %%
sys_sample100=df_emp.iloc[::100]
sys_sample100
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 130    Shirley  Female   5/1/1984         1:15 PM   41334    6.219
# 260     Gloria  Female  3/27/2007         1:44 AM   90730    2.491
# 391    Marilyn  Female  8/15/1989         9:14 AM  140502    9.989
# 522  Catherine  Female  8/31/2013         7:24 PM   58047   14.858
# 653      Debra  Female  5/28/2006         6:51 AM   42296   16.922
# 796  Catherine  Female  8/31/1986         6:20 PM   59970   12.801
# 922     Arthur    Male  12/5/2013         8:44 AM   86615    3.412
#
#     Senior Management                  Team
# 0                True             Marketing
# 130              True       Human Resources
# 260             False          Distribution
# 391              True                 Sales
# 522              True          Distribution
# 653             False               Product
# 796             False       Client Services
# ...

# %% [markdown]
# ## Stratified Sampling
# #### Perform a countplot and pieplot for Gender column.
# #### Select 20% startified sample from data based on Gender.
# #### Perform a countplot and pieplot for Gender column for the data sample.

# %%
df_emp.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male  4/18/1987         1:35 AM  115163   10.125
#
#   Senior Management             Team
# 0              True        Marketing
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services
# 5             False            Legal

# %%
sns.countplot(data=df_emp,x='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
value=df_emp['Gender'].value_counts()

plt.pie(value.values,labels=value.index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x798116c53700>,
# ...
#  [Text(-0.04973867214253067, 1.0988749084829892, 'Female'),
#   Text(0.049738672142530534, -1.0988749084829892, 'Male')],
#  [Text(-0.02713018480501673, 0.5993863137179941, '51.4%'),
#   Text(0.027130184805016652, -0.5993863137179941, '48.6%')])

# %%
strt=df_emp.groupby('Gender').apply(lambda x: x.sample(frac=.2))
strt
# Out:
#            First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# Gender
# Female 190      Carol  Female  3/19/1996         3:39 AM   57783    9.129
#        695      Sarah  Female   4/6/1999        11:17 AM  109517    5.146
#        632    Rebecca  Female  2/23/1990         3:21 PM  134673    6.878
#        131    Rebecca  Female  7/10/1992        12:23 AM   94231   17.517
#        987     Gloria  Female  12/8/2014         5:08 AM  136709   10.331
# ...               ...     ...        ...             ...     ...      ...
# Male   26       Craig    Male  2/27/2000         7:45 AM   37598    7.757
#        922     Arthur    Male  12/5/2013         8:44 AM   86615    3.412
#        48    Clarence    Male  3/26/1996         5:57 AM   93581    6.083
#        801       Ryan    Male  4/15/1988         5:18 AM   91109   17.499
#        413     Johnny    Male  9/14/1992         8:21 AM  115194    5.861
#
#            Senior Management                  Team
# Gender
# ...

# %%
from scipy.stats import norm
from scipy.stats import uniform

# %%
sns.countplot(data=strt,x='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
value=strt['Gender'].value_counts()

# %%
plt.pie(value.values,labels=value.index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7981146f26b0>,
# ...
#  [Text(-0.05644183823360293, 1.0985510087823924, 'Female'),
#   Text(0.056441941087370676, -1.0985510034979213, 'Male')],
#  [Text(-0.03078645721832887, 0.5992096411540321, '51.6%'),
#   Text(0.030786513320384002, -0.5992096382715933, '48.4%')])

# %% [markdown]
# ## Sampling Distributions and CLT
# ### Take a 10000 samples of sizes 1, 5, 10, 50 from a continuous uniform distribution a=1, b=11. Plot the sampling distribution of the sample mean.
# ### Calculate mean and variance of sampling distribution.
# ### Plot a histogram for the sampling distribution.
# ### Repeat for any distribution of your choice.
# ##### Hint: fix the scale of x-axis to be able to notice the difference.

# %%
a=1
b=11
sample_means1=[]
for i in range(10000):
  sample=np.random.uniform(low=1,high=12,size=1)
  sample_means1.append(sample.mean())
mean=np.mean(sample_means1)  
print(mean)
var=np.var(sample_means1) 
print(var)
st=uniform.stats(a,b-1)
print(st)
# Out:
# 6.509795531374435
# 10.021240113868823
# (6.0, 8.333333333333332)

# %%
sns.histplot(sample_means1,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
a=1
b=11
sample_means1=[]
for i in range(10000):
  sample=np.random.uniform(low=1,high=12,size=5)
  sample_means1.append(sample.mean())
mean=np.mean(sample_means1)  
print(mean)
var=np.var(sample_means1) 
print(var)
st=uniform.stats(a,b-1)
print(st)
sns.histplot(sample_means1,kde=True)
plt.show()
# Out:
# 6.515574469310377
# 2.029197725737748
# (6.0, 8.333333333333332)

# %%
a=1
b=11
sample_means1=[]
for i in range(10000):
  sample=np.random.uniform(low=1,high=12,size=10)
  sample_means1.append(sample.mean())
mean=np.mean(sample_means1)  
print(mean)
var=np.var(sample_means1) 
print(var)
st=uniform.stats(a,b-1)
print(st)
sns.histplot(sample_means1,kde=True)
plt.show()
# Out:
# 6.500279128069863
# 1.004625671644564
# (6.0, 8.333333333333332)

# %%
a=1
b=11
sample_means1=[]
for i in range(10000):
  sample=np.random.uniform(low=1,high=12,size=50)
  sample_means1.append(sample.mean())
mean=np.mean(sample_means1)  
print(mean)
var=np.var(sample_means1) 
print(var)
st=uniform.stats(a,b-1)
print(st)
sns.histplot(sample_means1,kde=True)
plt.show()
# Out:
# 6.500053622594035
# 0.19811614171325623
# (6.0, 8.333333333333332)

# %%
np.random.seed(42)
a=1
b=11
sample_means2=[]
for i in range(10000):
  sample2=np.random.uniform(low=1,high=12,size=100)
  sample_means2.append(sample2.mean())
mean=np.mean(sample_means2)  
print(mean)
var=np.var(sample_means2) 
print(var)
st=uniform.stats(a,b-1)
print(st)
sns.histplot(sample_means2,kde=True)
plt.show()
# Out:
# 6.503679347932861
# 0.1027257951702022
# (6.0, 8.333333333333332)

# %% [markdown]
# ### Repeat for any distribution of your choice.

# %%
from scipy.stats import expon

# %%
lambda_=10000
d=np.random.exponential(scale=lambda_)

# %%
sample2
# Out:
# array([ 4.19443459,  8.88573961, 11.96651758, 11.64059613, 11.62096255,
#        10.0036519 , 11.13530914,  6.50521028,  8.93538396,  2.5104997 ,
#        11.26421982,  9.74826988,  3.47528918,  6.69087135,  6.548138  ,
#         1.48149   ,  4.75140479,  2.68033983,  8.3649777 , 11.54284517,
#        11.86905427,  9.36359598,  4.24601495,  1.74407442,  4.41611994,
#         3.65770942,  4.60327627,  2.54919527,  9.00346293, 11.04159757,
#         9.60099689,  8.9573859 ,  2.32769461,  3.45785107,  9.31093153,
#        10.07568286,  9.24867664,  3.73413885, 11.52283441,  3.49924697,
#         7.41732567,  2.90630999,  3.78460159,  6.50495797, 11.70587295,
#         8.74085432,  2.47595744,  6.00805309,  6.0193519 ,  5.84221909,
#        10.88441466,  9.005647  ,  8.72775736, 11.40514012,  7.10888727,
#         3.35499558,  8.37117859,  8.95976729,  8.24970399, 11.76628277,
#         7.69590712,  2.55026727, 10.28858179,  1.88882033,  2.36003963,
# ...

# %%
lambda_=10000
np.random.seed(42)
sample_means2=[]
for i in range(10000):
  sample2=np.random.exponential(scale=lambda_,size=100)
  sample_means2.append(sample2.mean())
mean=np.mean(sample_means2)  
print(mean)
var=np.var(sample_means2) 
print(var)
st=expon.stats(scale=lambda_)
print(st)
sns.histplot(sample_means2,kde=True)
plt.show()
# Out:
# 10011.137903946767
# 1025180.1259554424
# (10000.0, 100000000.0)

# %% [markdown]
# ## Confidence Interval (CI)
# ### Within how many standard deviations the estimated sample mean should be located for CIs 90%, 92%, 95%, 98%, 99%.

# %%
from scipy.stats import norm
print(norm.ppf(.5+(.90/2)))
print(norm.ppf(.5+(.92/2)))
print(norm.ppf(.5+(.95/2)))
print(norm.ppf(.5+(.98/2)))
print(norm.ppf(.5+(.99/2)))
# Out:
# 1.6448536269514722
# 1.7506860712521692
# 1.959963984540054
# 2.3263478740408408
# 2.5758293035489004

# %% [markdown]
# ### Calculate the expected mean salary with 95% CI for each team for the employees data as follow:
# ##### Using z-value.
# ##### Using t-value.
# ##### Compare the results obtaind from the above calculation and write a conclusion.
# ##### Perform  sns.barplot() and check out the displayed confidence intervals. Compare with your results.

# %%
from scipy.stats import t

# %%
xbar=df_emp.loc[df_emp["Team"]=="Marketing"]["Salary"].mean()
std=df_emp.loc[df_emp["Team"]=="Marketing"]["Salary"].std()
SE=(std/np.sqrt(len(df_emp)))
z_value=norm.ppf(.5+(.95/2))
lenght_=len(df_emp)-1
tlue=t.ppf(.5+(.95/2),lenght_)
print(xbar)
print(std)
print(SE)
print(z_value)
print(tlue)
CI_z_h=xbar+z_value*SE
CI_z_l=xbar-z_value*SE
CI_t_h=xbar+tlue*SE
CI_t_l=xbar-tlue*SE
print(CI_z_h)
print(CI_z_l)
print(CI_t_h)
print(CI_t_l)
# Out:
# 90764.08108108108
# 32547.554818730507
# 1177.5292065598192
# 1.959963984540054
# 1.9630779751506866
# 93071.99591668235
# 88456.1662454798
# 93075.66273157533
# 88452.49943058683

# %%
xbar=df_emp.loc[df_emp["Team"]=="Business Development"]["Salary"].mean()
std=df_emp.loc[df_emp["Team"]=="Business Development"]["Salary"].std()
SE=(std/np.sqrt(len(df_emp)))
z_value=norm.ppf(.5+(.95/2))
lenght_=len(df_emp)-1
tlue=t.ppf(.5+(.95/2),lenght_)
print(xbar)
print(std)
print(SE)
print(z_value)
print(tlue)
CI_z_h=xbar+z_value*SE
CI_z_l=xbar-z_value*SE
CI_t_h=xbar+tlue*SE
CI_t_l=xbar-tlue*SE
print(CI_z_h)
print(CI_z_l)
print(CI_t_h)
print(CI_t_l)
# Out:
# 90520.39772727272
# 34003.949518592446
# 1230.219717564948
# 1.959963984540054
# 1.9630779751506866
# 92931.58406677106
# 88109.21138777438
# 92935.41495942057
# 88105.38049512487

# %%
xbar=df_emp.loc[df_emp["Team"]=="Client Services"]["Salary"].mean()
std=df_emp.loc[df_emp["Team"]=="Client Services"]["Salary"].std()
SE=(std/np.sqrt(len(df_emp)))
z_value=norm.ppf(.5+(.95/2))
lenght_=len(df_emp)-1
tlue=t.ppf(.5+(.95/2),lenght_)
print(xbar)
print(std)
print(SE)
print(z_value)
print(tlue)
CI_z_h=xbar+z_value*SE
CI_z_l=xbar-z_value*SE
CI_t_h=xbar+tlue*SE
CI_t_l=xbar-tlue*SE
print(CI_z_h)
print(CI_z_l)
print(CI_t_h)
print(CI_t_l)
# Out:
# 89336.65882352942
# 31388.107545296036
# 1135.581876398183
# 1.959963984540054
# 1.9630779751506866
# 91562.35840276627
# 87110.95924429256
# 91565.89459406698
# 87107.42305299186

# %%
xbar=df_emp.loc[df_emp["Team"]=="Finance"]["Salary"].mean()
std=df_emp.loc[df_emp["Team"]=="Finance"]["Salary"].std()
SE=(std/np.sqrt(len(df_emp)))
z_value=norm.ppf(.5+(.95/2))
lenght_=len(df_emp)-1
tlue=t.ppf(.5+(.95/2),lenght_)
print(xbar)
print(std)
print(SE)
print(z_value)
print(tlue)
CI_z_h=xbar+z_value*SE
CI_z_l=xbar-z_value*SE
CI_t_h=xbar+tlue*SE
CI_t_l=xbar-tlue*SE
print(CI_z_h)
print(CI_z_l)
print(CI_t_h)
print(CI_t_l)
# Out:
# 94519.075
# 34888.40849604219
# 1262.2183203402249
# 1.959963984540054
# 1.9630779751506866
# 96992.97744849348
# 92045.17255150652
# 96996.90798449158
# 92041.24201550841

# %%
xbar=df_emp.loc[df_emp["Team"]=="Distribution"]["Salary"].mean()
std=df_emp.loc[df_emp["Team"]=="Distribution"]["Salary"].std()
SE=(std/np.sqrt(len(df_emp)))
z_value=norm.ppf(.5+(.95/2))
lenght_=len(df_emp)-1
tlue=t.ppf(.5+(.95/2),lenght_)
print(xbar)
print(std)
print(SE)
print(z_value)
print(tlue)
CI_z_h=xbar+z_value*SE
CI_z_l=xbar-z_value*SE
CI_t_h=xbar+tlue*SE
CI_t_l=xbar-tlue*SE
print(CI_z_h)
print(CI_z_l)
print(CI_t_h)
print(CI_t_l)
# Out:
# 85849.1
# 34591.22825064377
# 1251.4667164019816
# 1.959963984540054
# 1.9630779751506866
# 88301.92969199849
# 83396.27030800152
# 88305.82674760289
# 83392.37325239713

# %%
xbar=df_emp.loc[df_emp["Team"]=="Engineering"]["Salary"].mean()
std=df_emp.loc[df_emp["Team"]=="Engineering"]["Salary"].std()
SE=(std/np.sqrt(len(df_emp)))
z_value=norm.ppf(.5+(.95/2))
lenght_=len(df_emp)-1
tlue=t.ppf(.5+(.95/2),lenght_)
print(xbar)
print(std)
print(SE)
print(z_value)
print(tlue)
CI_z_h=xbar+z_value*SE
CI_z_l=xbar-z_value*SE
CI_t_h=xbar+tlue*SE
CI_t_l=xbar-tlue*SE
print(CI_z_h)
print(CI_z_l)
print(CI_t_h)
print(CI_t_l)
# Out:
# 94369.40506329114
# 33128.774280389545
# 1198.5569886877297
# 1.959963984540054
# 1.9630779751506866
# 96718.53359453788
# 92020.2765320444
# 96722.26588974695
# 92016.54423683533

# %%
xbar=df_emp.loc[df_emp["Team"]=="Human Resources"]["Salary"].mean()
std=df_emp.loc[df_emp["Team"]=="Human Resources"]["Salary"].std()
SE=(std/np.sqrt(len(df_emp)))
z_value=norm.ppf(.5+(.95/2))
lenght_=len(df_emp)-1
tlue=t.ppf(.5+(.95/2),lenght_)
print(xbar)
print(std)
print(SE)
print(z_value)
print(tlue)
CI_z_h=xbar+z_value*SE
CI_z_l=xbar-z_value*SE
CI_t_h=xbar+tlue*SE
CI_t_l=xbar-tlue*SE
print(CI_z_h)
print(CI_z_l)
print(CI_t_h)
print(CI_t_l)
# Out:
# 91145.17105263157
# 33003.806206916255
# 1194.03580246585
# 1.959963984540054
# 1.9630779751506866
# 93485.43822171602
# 88804.90388354713
# 93489.15643799366
# 88801.18566726948

# %%
xbar=df_emp.loc[df_emp["Team"]=="Legal"]["Salary"].mean()
std=df_emp.loc[df_emp["Team"]=="Legal"]["Salary"].std()
SE=(std/np.sqrt(len(df_emp)))
z_value=norm.ppf(.5+(.95/2))
lenght_=len(df_emp)-1
tlue=t.ppf(.5+(.95/2),lenght_)
print(xbar)
print(std)
print(SE)
print(z_value)
print(tlue)
CI_z_h=xbar+z_value*SE
CI_z_l=xbar-z_value*SE
CI_t_h=xbar+tlue*SE
CI_t_l=xbar-tlue*SE
print(CI_z_h)
print(CI_z_l)
print(CI_t_h)
print(CI_t_l)
# Out:
# 88066.40298507463
# 32946.885027295204
# 1191.976466461996
# 1.959963984540054
# 1.9630779751506866
# 90402.63392975945
# 85730.1720403898
# 90406.34573328412
# 85726.46023686514

# %%
xbar=df_emp.loc[df_emp["Team"]=="Sales"]["Salary"].mean()
std=df_emp.loc[df_emp["Team"]=="Sales"]["Salary"].std()
SE=(std/np.sqrt(len(df_emp)))
z_value=norm.ppf(.5+(.95/2))
lenght_=len(df_emp)-1
tlue=t.ppf(.5+(.95/2),lenght_)
print(xbar)
print(std)
print(SE)
print(z_value)
print(tlue)
CI_z_h=xbar+z_value*SE
CI_z_l=xbar-z_value*SE
CI_t_h=xbar+tlue*SE
CI_t_l=xbar-tlue*SE
print(CI_z_h)
print(CI_z_l)
print(CI_t_h)
print(CI_t_l)
# Out:
# 91724.81944444444
# 31003.12006303554
# 1121.653518122225
# 1.959963984540054
# 1.9630779751506866
# 93923.21994309664
# 89526.41894579223
# 93926.71276162045
# 89522.92612726842

# %%
xbar=df_emp.loc[df_emp["Team"]=="Product"]["Salary"].mean()
std=df_emp.loc[df_emp["Team"]=="Product"]["Salary"].std()
SE=(std/np.sqrt(len(df_emp)))
z_value=norm.ppf(.5+(.95/2))
lenght_=len(df_emp)-1
tlue=t.ppf(.5+(.95/2),lenght_)
print(xbar)
print(std)
print(SE)
print(z_value)
print(tlue)
CI_z_h=xbar+z_value*SE
CI_z_l=xbar-z_value*SE
CI_t_h=xbar+tlue*SE
CI_t_l=xbar-tlue*SE
print(CI_z_h)
print(CI_z_l)
print(CI_t_h)
print(CI_t_l)
# Out:
# 86935.96385542168
# 32005.495537045637
# 1157.918190020308
# 1.959963984540054
# 1.9630779751506866
# 89205.44180490529
# 84666.48590593807
# 89209.04755127689
# 84662.88015956647

# %%
plt.figure(figsize=(11,5))
sns.barplot(x=df_emp['Team'],y=df_emp['Salary'])
# Out:
# <Axes: xlabel='Team', ylabel='Salary'>

# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# ### Plot a histogram of salary.

# %%
sns.histplot(x=df_emp['Salary'])
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %% [markdown]
# ### Find mean, standard deviation, and count of salary.

# %%
mean=df_emp['Salary'].mean()
print(mean)
std=df_emp['Salary'].std()
print(std)
print(df_emp['Salary'].count())
# Out:
# 90433.19633507854
# 32864.66528235602
# 764

# %% [markdown]
# ### For all of the following Hypothesis Tests you must:
# #### Define your null and alternate Hypothesis.
# #### Perform z-test and t-test. (this is only used for comparison. However, you should know z-test is used for proportion and t-test is used for mean).
# #### State which test you need (two tailed / one tailed - right or left )
# #### The calculation must be performed using the Hypothesis test equations.
# #### i.e., calculate the standard error then calculate the z or t values then calculate p-value once using z-distribution and once using t-distribution.
# #### Repeat using statsmodels.stats.weightstats.ztest() and scipy.stats.ttest_1samp() to confirm the obtained results.
# #### Write down your conclusion (Reject H0 or not).

# %% [markdown]
# ### The claim is that the mean salary is 90000. Check if the data supports this claim or not. i.e., reject this claim or not.

# %%
mean=df_emp['Salary'].mean()
std=df_emp['Salary'].std()
SE=std/np.sqrt(len(df_emp['Salary']))
t_value=(mean-90000)/SE
t_value
# Out:
# 0.3643361288778422

# %%
leng_=len(df_emp['Salary'])-1
#p_value
(1-t.cdf(t_value,leng_))*2
# Out:
# 0.715707969136572

# %%
from scipy import stats as st

# %%
import statsmodels.api as sm

# %%
sm.stats.ztest(df_emp['Salary'],value=90000)
# Out:
# (0.3643361288778422, 0.7156070241477364)

# %%
st.ttest_1samp(df_emp['Salary'],90000)
# Out:
# TtestResult(statistic=0.3643361288778422, pvalue=0.7157079691365718, df=763)

# %% [markdown]
# ### The claim is that the mean salary is 100000. Check if the data supports this claim or not. i.e., reject this claim or not.

# %%
mean=df_emp['Salary'].mean()
std=df_emp['Salary'].std()
SE=std/np.sqrt(len(df_emp['Salary']))
t_value=(mean-100000)/SE
t_value
# Out:
# -8.04607964280197

# %%
st.norm.cdf(t_value)*2
# Out:
# 8.548837039392978e-16

# %%
leng_=len(df_emp['Salary'])-1
#p_value
(t.cdf(t_value,leng_))*2
# Out:
# 3.266925104077574e-15

# %%
sm.stats.ztest(df_emp['Salary'],value=100000)
# Out:
# (-8.04607964280197, 8.548837039392978e-16)

# %%
st.ttest_1samp(df_emp['Salary'],100000)
# Out:
# TtestResult(statistic=-8.04607964280197, pvalue=3.266925104077574e-15, df=763)

# %% [markdown]
# ### The claim is that the mean salary is greater than or equal to 92000. Check if the data supports this claim or not. i.e., reject this claim or not.

# %%
mean=df_emp['Salary'].mean()
std=df_emp['Salary'].std()
SE=std/np.sqrt(len(df_emp['Salary']))
t_value=(mean-92000)/SE
t_value
# Out:
# -1.3177470254581203

# %%
st.norm.cdf(t_value)
# Out:
# 0.09379417338868268

# %%
sm.stats.ztest(df_emp['Salary'],value=92000,alternative='smaller')
# Out:
# (-1.3177470254581203, 0.09379417338868268)

# %%
st.ttest_1samp(df_emp['Salary'],92000,alternative='less')
# Out:
# TtestResult(statistic=-1.3177470254581203, pvalue=0.0939919301061736, df=763)

# %% [markdown]
# ### The claim is that the mean salary is greater than or equal to 93000. Check if the data supports this claim or not. i.e., reject this claim or not.

# %%
mean=df_emp['Salary'].mean()
std=df_emp['Salary'].std()
SE=std/np.sqrt(len(df_emp['Salary']))
t_value=(mean-93000)/SE
t_value
# Out:
# -2.1587886026261014

# %%
st.norm.cdf(t_value)
# Out:
# 0.015433285555675419

# %%
sm.stats.ztest(df_emp['Salary'],value=93000,alternative='smaller')
# Out:
# (-2.1587886026261014, 0.015433285555675419)

# %%
st.ttest_1samp(df_emp['Salary'],93000,alternative='less')
# Out:
# TtestResult(statistic=-2.1587886026261014, pvalue=0.015588852380116005, df=763)

# %% [markdown]
# ### The claim is that the mean salary is less than or equal to 88000. Check if the data supports this claim or not. i.e., reject this claim or not.

# %%
mean=df_emp['Salary'].mean()
std=df_emp['Salary'].std()
SE=std/np.sqrt(len(df_emp['Salary']))
t_value=(mean-88000)/SE
t_value
# Out:
# 2.0464192832138046

# %%
1-st.norm.cdf(t_value)
# Out:
# 0.02035756823028878

# %%
sm.stats.ztest(df_emp['Salary'], value=88000,alternative='larger')
# Out:
# (2.0464192832138046, 0.020357568230288822)

# %%
st.ttest_1samp(df_emp['Salary'],88000,alternative='greater')
# Out:
# TtestResult(statistic=2.0464192832138046, pvalue=0.020528674104732036, df=763)

# %% [markdown]
# ### The claim is that the mean salary is less than or equal to 90000. Check if the data supports this claim or not. i.e., reject this claim or not.

# %%
mean=df_emp['Salary'].mean()
std=df_emp['Salary'].std()
SE=std/np.sqrt(len(df_emp['Salary']))
t_value=(mean-90000)/SE
t_value
# Out:
# 0.3643361288778422

# %%
1-st.norm.cdf(t_value)
# Out:
# 0.3578035120738682

# %%
sm.stats.ztest(df_emp['Salary'],value=90000,alternative='larger')
# Out:
# (0.3643361288778422, 0.3578035120738682)

# %%
st.ttest_1samp(df_emp['Salary'],90000,alternative='greater')
# Out:
# TtestResult(statistic=0.3643361288778422, pvalue=0.3578539845682859, df=763)
